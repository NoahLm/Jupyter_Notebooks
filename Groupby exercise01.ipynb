# %%
import pandas as pd

# %%
surveys_df = pd.read_csv('sample_data/species.csv')

# %%
surevys_df
# Out:
#        record_id  month  day  year  ...  species_id  sex hindfoot_length  weight
# 0              1      7   16  1977  ...          NL    M            32.0     NaN
# 1              2      7   16  1977  ...          NL    M            33.0     NaN
# 2              3      7   16  1977  ...          DM    F            37.0     NaN
# 3              4      7   16  1977  ...          DM    M            36.0     NaN
# 4              5      7   16  1977  ...          DM    M            35.0     NaN
# ...          ...    ...  ...   ...  ...         ...  ...             ...     ...
# 35544      35545     12   31  2002  ...          AH  NaN             NaN     NaN
# 35545      35546     12   31  2002  ...          AH  NaN             NaN     NaN
# 35546      35547     12   31  2002  ...          RM    F            15.0    14.0
# 35547      35548     12   31  2002  ...          DO    M            36.0    51.0
# 35548      35549     12   31  2002  ...         NaN  NaN             NaN     NaN
#
# ...

# %%
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
surveys_df['weight'].count()
# Out:
# 32283

# %%
surveys_df['weight'].mean()
# Out:
# 42.672428212991356

# %%
grouped_data1 = surveys_df['sex']

# %%
grouped_data1
# Out:
# 0          M
# 1          M
# 2          F
# 3          M
# 4          M
#         ...
# 35544    NaN
# 35545    NaN
# 35546      F
# 35547      M
# 35548    NaN
# Name: sex, Length: 35549, dtype: object

# %%
grouped_data1.describe()
# Out:
# count     33038
# unique        2
# top           M
# freq      17348
# Name: sex, dtype: object

# %%
grouped_data2 = surveys_df.groupby('species_id')

# %%
grouped_data2.describe()
# Out:
#            record_id                              ... weight
#                count          mean           std  ...    50%     75%    max
# species_id                                        ...
# AB             303.0  13201.702970   5835.874869  ...    NaN     NaN    NaN
# AH             437.0  21631.716247   7194.381201  ...    NaN     NaN    NaN
# AS               2.0  19760.000000   1170.968830  ...    NaN     NaN    NaN
# BA              46.0  18586.043478    921.349203  ...    8.0    9.00   18.0
# CB              50.0  18300.460000   7271.702586  ...    NaN     NaN    NaN
# CM              13.0   4055.000000   2789.266660  ...    NaN     NaN    NaN
# CQ              16.0   5718.062500   1899.301607  ...    NaN     NaN    NaN
# CS               1.0  15878.000000           NaN  ...    NaN     NaN    NaN
# CT               1.0  28988.000000           NaN  ...    NaN     NaN    NaN
# CU               1.0  21209.000000           NaN  ...    NaN     NaN    NaN
# ...

# %%
grouped_data3=surveys_df.groupby(['species_id','sex'])

# %%
grouped_data3.mean()
# Out:
#                    record_id      month  ...  hindfoot_length      weight
# species_id sex                           ...
# AH         M    22330.000000   6.000000  ...              NaN         NaN
# BA         F    18658.451613   6.387097  ...        13.161290    9.161290
#            M    18385.857143   8.214286  ...        12.642857    7.357143
# DM         F    15448.699605   6.403382  ...        35.712692   41.609685
#            M    16071.827944   6.288658  ...        36.188229   44.353134
# DO         F    17035.387615   6.071101  ...        35.486334   48.531250
#            M    18670.820738   6.137083  ...        35.698780   49.135102
# DS         F     6015.080808   6.536195  ...        49.583174  117.749548
#            M     6151.857480   6.210236  ...        50.301939  122.290984
# NL         F    14693.844444   6.863704  ...        32.024194  154.282209
#            M    13648.402390   6.962151  ...        32.577434  165.652893
# ...
